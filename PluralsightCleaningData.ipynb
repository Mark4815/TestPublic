# %% [markdown]
# <a href="https://colab.research.google.com/github/Mark4815/TestPublic/blob/main/PluralsightCleaningData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-60749f29-fbe4-43ee-ba55-5d67b1448caf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-60749f29-fbe4-43ee-ba55-5d67b1448caf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
data_df = pd.read_csv('hotel_bookings.csv')
print("The dataset contains", data_df.shape[0], "rows and", data_df.shape[1],"columns")
# Out:
# The dataset contains 119390 rows and 32 columns

# %%
data_df.head(7)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
# ...

# %%
pd.set_option("display.max_columns", None)

# %%
data_df.head(7)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
# ...

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
data_df.describe()
#Determining different metrics per column. Call out of Adults which is 0, which isn't possible.
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
data_df.isnull().sum()/len(data_df)*100
#Determines % of values per column that are null. Possibility to remove columns altogether where this is too high (Company)
# Out:
# hotel                              0.000000
# is_canceled                        0.000000
# lead_time                          0.000000
# arrival_date_year                  0.000000
# arrival_date_month                 0.000000
# arrival_date_week_number           0.000000
# arrival_date_day_of_month          0.000000
# stays_in_weekend_nights            0.000000
# stays_in_week_nights               0.000000
# adults                             0.000000
# children                           0.003350
# babies                             0.000000
# meal                               0.000000
# country                            0.408744
# market_segment                     0.000000
# distribution_channel               0.000000
# is_repeated_guest                  0.000000
# previous_cancellations             0.000000
# previous_bookings_not_canceled     0.000000
# reserved_room_type                 0.000000
# assigned_room_type                 0.000000
# ...

# %%
data_df.drop('Company', inplace=True, axis=1)
#axis = 1 says that we want to remove columns.

# %%
data_df.isnull().sum()
#summing up the amount of null values in each column.
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
data_df["children"].value_counts()
#counts the number of instances each value appears in the given column (majority have no children)
# Out:
# children
# 0.0     110796
# 1.0       4861
# 2.0       3652
# 3.0         76
# 10.0         1
# Name: count, dtype: int64

# %%
data_df["adults"].value_counts()
# Out:
# adults
# 2     89680
# 1     23027
# 3      6202
# 0       403
# 4        62
# 26        5
# 5         2
# 27        2
# 20        2
# 40        1
# 55        1
# 50        1
# 6         1
# 10        1
# Name: count, dtype: int64

# %%
data_df.sample(10)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 79274     City Hotel            0          3               2016
# 33169   Resort Hotel            0         44               2017
# 68217     City Hotel            1        104               2017
# 114960    City Hotel            0          1               2017
# 107121    City Hotel            0        137               2017
# 50378     City Hotel            1         64               2016
# 45084     City Hotel            1        102               2015
# 35876   Resort Hotel            0        134               2017
# 79607     City Hotel            0          0               2015
# 80777     City Hotel            1        180               2016
#
#        arrival_date_month  arrival_date_week_number  \
# 79274                 May                        20
# 33169            February                         7
# 68217                 May                        20
# ...

# %%
data_df.duplicated().sum()
#Outputs true if any specific row matches with any other row. By then wrapping a sum() round it, you are counting the number of duplicate rows.
# Out:
# np.int64(31994)

# %%
data_df.drop_duplicates(inplace=True, keep='first')
#this drops all duplicate rows, keeping the first iteration of the row flagged. Same with 'last' if you wanted to keep the last record found instead.

# %%
data_df['reservation_status_date'] = pd.to_datetime(data_df['reservation_status_date'])
#changes the format of the specified column to what you want. In this case, datetime format.

# %%
data_df['reservation_status_year'] = data_df['reservation_status_date'].dt.year
data_df.head()
#this is taking a column and adding a new column with it formatted in a certian way, you can also use month, day, week, dayofweek
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-16-2669178146.py in <cell line: 0>()
# ----> 1 data_df['reservation_status_year'] = data_df['reservation_status_date'].dt.year
#       2 data_df.head()
#       3 #this is taking a column and adding a new column with it formatted in a certian way, you can also use month, day, week, dayofweek
#
# NameError: name 'data_df' is not defined

# %%
cat_cols = [col for col in data_df.columns if data_df[col].dtype=='object']
cat_cols
#this gives you a list comphrehension for the columns where the data type is object.
# Out:
# ['hotel',
#  'arrival_date_month',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'reserved_room_type',
#  'assigned_room_type',
#  'deposit_type',
#  'customer_type',
#  'reservation_status']

# %%
cat_df = data_df[cat_cols]
cat_df.head()
#This takes the above and uses it against the df to create a revised set of data that are just objects.
# Out:
#           hotel arrival_date_month meal country market_segment  \
# 0  Resort Hotel               July   BB     PRT         Direct
# 1  Resort Hotel               July   BB     PRT         Direct
# 2  Resort Hotel               July   BB     GBR         Direct
# 3  Resort Hotel               July   BB     GBR      Corporate
# 4  Resort Hotel               July   BB     GBR      Online TA
#
#   distribution_channel reserved_room_type assigned_room_type deposit_type  \
# 0               Direct                  C                  C   No Deposit
# 1               Direct                  C                  C   No Deposit
# 2               Direct                  A                  C   No Deposit
# 3            Corporate                  A                  A   No Deposit
# 4                TA/TO                  A                  A   No Deposit
#
#   customer_type reservation_status
# 0     Transient          Check-Out
# 1     Transient          Check-Out
# ...

# %%
cat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87396 entries, 0 to 119389
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   hotel                 87396 non-null  object
#  1   arrival_date_month    87396 non-null  object
#  2   meal                  87396 non-null  object
#  3   country               86944 non-null  object
#  4   market_segment        87396 non-null  object
#  5   distribution_channel  87396 non-null  object
#  6   reserved_room_type    87396 non-null  object
#  7   assigned_room_type    87396 non-null  object
#  8   deposit_type          87396 non-null  object
#  9   customer_type         87396 non-null  object
#  10  reservation_status    87396 non-null  object
# dtypes: object(11)
# memory usage: 8.0+ MB

# %%
cat_df.head()
# Out:
#           hotel  arrival_date_month meal country market_segment  \
# 0  Resort Hotel                 NaN   BB     PRT         Direct
# 1  Resort Hotel                 NaN   BB     PRT         Direct
# 2  Resort Hotel                 NaN   BB     GBR         Direct
# 3  Resort Hotel                 NaN   BB     GBR      Corporate
# 4  Resort Hotel                 NaN   BB     GBR      Online TA
#
#   distribution_channel reserved_room_type assigned_room_type deposit_type  \
# 0               Direct                  C                  C   No Deposit
# 1               Direct                  C                  C   No Deposit
# 2               Direct                  A                  C   No Deposit
# 3            Corporate                  A                  A   No Deposit
# 4                TA/TO                  A                  A   No Deposit
#
#   customer_type reservation_status
# 0     Transient          Check-Out
# 1     Transient          Check-Out
# ...

# %%
data_df["arrival_date_month"].isna().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-15-393791639.py in <cell line: 0>()
# ----> 1 data_df["arrival_date_month"].isna().sum()
#
# NameError: name 'data_df' is not defined

# %%
cat_df['arrival_date_month'] = cat_df['arrival_date_month'].map({'January':1, 'February':2, 'March':3, 'April':4, 'May':5})
cat_df.head(50)
# Out:
#            hotel  arrival_date_month meal country market_segment  \
# 0   Resort Hotel                 NaN   BB     PRT         Direct
# 1   Resort Hotel                 NaN   BB     PRT         Direct
# 2   Resort Hotel                 NaN   BB     GBR         Direct
# 3   Resort Hotel                 NaN   BB     GBR      Corporate
# 4   Resort Hotel                 NaN   BB     GBR      Online TA
# 6   Resort Hotel                 NaN   BB     PRT         Direct
# 7   Resort Hotel                 NaN   FB     PRT         Direct
# 8   Resort Hotel                 NaN   BB     PRT      Online TA
# 9   Resort Hotel                 NaN   HB     PRT  Offline TA/TO
# 10  Resort Hotel                 NaN   BB     PRT      Online TA
# 11  Resort Hotel                 NaN   HB     PRT      Online TA
# 12  Resort Hotel                 NaN   BB     USA      Online TA
# 13  Resort Hotel                 NaN   HB     ESP      Online TA
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [2,3,4]
y = [4,3,2]
print(x)
print(y)

plt.plot(x,y)
# Out:
# [2, 3, 4]
# [4, 3, 2]

# %%
# %matplotlib inline
plt.plot(data_df['arrival_date_week_number'], data_df['lead_time'])
#Running based off two columns into the dataframe for x and y axis.
plt.xlabel('Week Number')
plt.ylabel('lead_time')
plt.title('Lead Time per Week')
plt.show()

# %%
# %matplotlib inline

y = [45,49,54,38,41,80,90,14,60]
x = ['Jan 1', 'Feb 2', 'Mar 31', 'Apr 23', 'May 14', 'Jun 18', 'Jul 15', 'Aug 11', 'Sept 12']
plt.plot(x,y)

# %%
data_df.plot()
# Out:
# <Axes: >

# %%
data_df.plot(x='arrival_date_year', y='lead_time', marker='o', markerfacecolor='red')
# Out:
# <Axes: xlabel='arrival_date_year'>

# %%
data_refined = data_df[data_df['arrival_date_year']==2015]
data_refined = data_df[data_df['lead_time']<700]
data_refined.head()
data_refined.plot(x='arrival_date_year', y='lead_time', kind='hist')

#Further options given to display a visual.
# Out:
# <Axes: ylabel='Frequency'>

# %%
#pivot allows you to stack areas into visualisations, by organising the data in a certian way.

pivotenrolled = data_df.pivot_table(index='arrival_date_month', columns='hotel', values='lead_time')
pivotenrolled.head()
# Out:
# hotel               City Hotel  Resort Hotel
# arrival_date_month
# April                99.119519     85.917706
# August              130.749527    103.495096
# December             84.767183     56.075529
# February             52.815307     39.930068
# January              56.611884     26.056088

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=pivotenrolled)
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-28-2061921910.py in <cell line: 0>()
#       1 from google.colab import sheets
# ----> 2 sheet = sheets.InteractiveSheet(df=pivotenrolled)
#
# /usr/local/lib/python3.11/dist-packages/google/colab/sheets.py in __init__(self, title, url, sheet_id, df, worksheet_id, worksheet_name, credentials, include_column_headers, display, backend)
#     147       url = f'https://docs.google.com/spreadsheets/d/{sheet_id}'
#     148     self._credentials = credentials
# --> 149     self._ensure_gspread_client()
#     150
#     151     self.sheet = self._load_or_create_sheet(url, title)
#
# /usr/local/lib/python3.11/dist-packages/google/colab/sheets.py in _ensure_gspread_client(self)
#     217     global _gspread_client
#     218     if _gspread_client is None:
# ...

# %%
pivotenrolled.plot(kind='area')
# Out:
# <Axes: xlabel='arrival_date_month'>
